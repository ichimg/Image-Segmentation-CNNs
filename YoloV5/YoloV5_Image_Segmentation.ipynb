# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 /content/drive/MyDrive/yolov5
# %cd /content/drive/MyDrive/yolov5
# !pip install -r requirements.txt

# %%
# !wget https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5s.pt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="unLbw0bkS23mYPtwjowH")
project = rf.workspace("harsh-avhnv").project("food-image-segmentation-yolov5")
dataset = project.version(1).download("yolov5")

# %%
# !pip install ultralytics

# %%
# !python /content/drive/MyDrive/yolov5/segment/train.py --img 640 --batch 16 --epochs 40 --data /content/YOLOV5-1/data.yaml --weights /content/drive/MyDrive/yolov5/yolov5s-seg.pt
# Out:
# 2024-01-07 18:47:27.754218: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-07 18:47:27.754284: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-07 18:47:27.756128: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/drive/MyDrive/yolov5/segment/predict.py --weights /content/drive/MyDrive/yolov5/runs/train-seg/exp10/weights/best.pt --img 640 --conf 0.25 --source /content/YOLOV5-1/test/images

# %%
# !python /content/drive/MyDrive/yolov5/segment/train.py --img 640 --batch 16 --epochs 10 --data /content/FOOD-IMAGE-SEGMENTATION-YOLOv5-1/data.yaml --weights /content/drive/MyDrive/yolov5/yolov5s-seg.pt
# Out:
# 2024-01-07 21:46:09.810871: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-07 21:46:09.810921: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-07 21:46:09.812368: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
